# %% [markdown]
# # Matplotlib graphs, and surveying the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
white_df = pd.read_csv("winequality-white.csv", sep=';')
red_wine_df = pd.read_csv("winequality-red.csv", sep=';')
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
#the quality values are only from 3 to 10
white_df[white_df["quality"] == 3]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 251             8.5             0.260         0.21           16.20      0.074
# 253             5.8             0.240         0.44            3.50      0.029
# 294             9.1             0.590         0.38            1.60      0.066
# 445             7.1             0.320         0.32           11.00      0.038
# 740             6.9             0.390         0.40            4.60      0.022
# 873            10.3             0.170         0.47            1.40      0.037
# 1034            7.9             0.640         0.46           10.60      0.244
# 1229            8.3             0.330         0.42            1.15      0.033
# 1417            8.6             0.550         0.35           15.55      0.057
# 1484            7.5             0.320         0.24            4.60      0.053
# 1688            6.7             0.250         0.26            1.55      0.041
# ...

# %%
bin_values = np.arange(start=0, stop=10, step=1)
white_df['quality'].hist(bins=bin_values, figsize=[14,6])

# %%
# # x = np.arange(0, 5, 0.1)
# # y = np.arange(0, 5, .1)
# plt.plot(white_df['alcohol'], white_df['quality'])
# plt.show()

# %%
pd.set_option('display.max_rows', 500)

# Groupby quality to give the count for each quality value
gb_qual = white_df.groupby("alcohol")
gb_qual.count()
# Out:
#            fixed acidity  volatile acidity  citric acid  residual sugar  \
# alcohol
# 8.000000               2                 2            2               2
# 8.400000               3                 3            3               3
# 8.500000               9                 9            9               9
# 8.600000              23                23           23              23
# 8.700000              78                78           78              78
# 8.800000             107               107          107             107
# 8.900000              95                95           95              95
# 9.000000             185               185          185             185
# 9.100000             144               144          144             144
# 9.200000             199               199          199             199
# 9.300000             134               134          134             134
# 9.400000             229               229          229             229
# ...

# %%
#Groupby quality but means for each value
gb_qual.mean()
# Out:
#            fixed acidity  volatile acidity  citric acid  residual sugar  \
# alcohol
# 8.000000        4.350000          0.202500     0.220000        3.025000
# 8.400000        6.266667          0.330000     0.193333        4.166667
# 8.500000        6.966667          0.307778     0.398889       11.105556
# 8.600000        7.200000          0.293913     0.440435       12.386957
# 8.700000        7.079487          0.290192     0.457821       12.950000
# 8.800000        6.906542          0.265280     0.352243       13.871028
# 8.900000        6.977895          0.269737     0.365263       11.792105
# 9.000000        6.852973          0.284189     0.330703       11.522703
# 9.100000        6.963889          0.288819     0.351458       10.739931
# 9.200000        6.919598          0.296709     0.353317        9.277136
# 9.300000        6.895522          0.313918     0.359776        8.911194
# 9.400000        6.758515          0.299105     0.332838        8.151747
# ...

# %%
list(white_df)
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
#We could remove the pH column, citric acid, fixed acidity, and density because those values are not changing
gb_alc = white_df.groupby("quality")
mean_quality_gb = gb_alc['fixed acidity',
 'volatile acidity',
 'citric acid',
 'residual sugar',
 'chlorides',
 'free sulfur dioxide',
 'total sulfur dioxide',
 'density',
 'pH',
 'sulphates',
 'alcohol'].mean()

mean_quality_gb
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %%
# quality_count = gb_qual.count()
# quality_count['alcohol']

# %%
gb_qual = red_wine_df.groupby("quality")
gb_qual.count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   10                10           10              10
# 4                   53                53           53              53
# 5                  681               681          681             681
# 6                  638               638          638             638
# 7                  199               199          199             199
# 8                   18                18           18              18
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# quality
# 3               10                   10                    10       10   10
# 4               53                   53                    53       53   53
# 5              681                  681                   681      681  681
# 6              638                  638                   638      638  638
# 7              199                  199                   199      199  199
# ...

# %%
mean_quality_gb["total_num_wines"] = quality_count['alcohol']
mean_quality_gb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'alcohol'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1857b6939722> in <module>
# ...

# %%
white_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(15,15))
sns_plot = sns.heatmap(white_df.corr(), annot=True, cmap="coolwarm")
plt_title("Wine Correlation Heatmap")
plt.show()
sns.savefig("wine-correlation-heatmap.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a273fe0814d4> in <module>
#       1 plt.figure(figsize=(15,15))
#       2 sns_plot = sns.heatmap(white_df.corr(), annot=True, cmap="coolwarm")
# ----> 3 plt_title("Wine Correlation Heatmap")
#       4 plt.show()
#       5 sns.savefig("wine-correlation-heatmap.png")
#
# NameError: name 'plt_title' is not defined

# %%
# #concatenate both red and white wine data
# #red wine is 0 and white wine is 1
# red_wine_df = pd.read_csv("winequality-red.csv", sep=';')
# white_df = pd.read_csv("winequality-white.csv", sep=';')
# white_wine_df = white_df.copy()
# white_wine_df["color"] = "white"
# red_wine_df["color"] = "red"
# # red_wine_df
# # white_wine_df
# concat_df = pd.concat([red_wine_df, white_wine_df], ignore_index=True)
# concat_df = pd.get_dummies(concat_df, columns=['color'])
# concat_df.drop(columns=["color_red"])

# %%
red_wine_df = pd.read_csv("winequality-red.csv", sep=';')
white_df = pd.read_csv("winequality-white.csv", sep=';')
white_wine_df = white_df.copy()
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Remove quality of 9's, because only white wine data has five 9 qualities which would skew our data
new_white_df = white_wine_df[white_wine_df["quality"] <= 8].copy()
#get random sample
rand_white_df = new_white_df.sample(1599,random_state=54).reset_index(drop=True)
rand_white_df
#add color rows
rand_white_df["color"] = "white"
red_wine_df["color"] = "red"
# rand_white_df
# red_wine_df
new_combinedf = pd.concat([red_wine_df, rand_white_df,])
#red wine is 0 and white wine is 1
combinedf = pd.get_dummies(new_combinedf, columns=['color'])
combinedf = combinedf.drop(columns=["color_red"]).copy()
# combinedf = next_combinedf.copy()
combinedf
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00            1.90      0.076
# 1               7.8              0.88         0.00            2.60      0.098
# 2               7.8              0.76         0.04            2.30      0.092
# 3              11.2              0.28         0.56            1.90      0.075
# 4               7.4              0.70         0.00            1.90      0.076
# ...             ...               ...          ...             ...        ...
# 1594            5.2              0.37         0.33            1.20      0.028
# 1595            6.8              0.25         0.18            1.40      0.056
# 1596            6.4              0.40         0.25            4.20      0.032
# 1597            7.8              0.21         0.49            1.35      0.052
# 1598            7.5              0.31         0.24            7.10      0.031
#
# ...

# %%
bin_values = np.arange(start=0, stop=10, step=2)
white_df['quality'].hist(bins=bin_values, figsize=[14,6])
plt.title("White Wine Original (4898 data points)")
plt.show()

# %%
bin_values = np.arange(start=0, stop=9, step=2)
rand_white_df['quality'].hist(bins=bin_values, figsize=[14,6])
plt.title("White Wine Randomized (1599 random data points)")
plt.show()

# %%
bin_values = np.arange(start=0, stop=9, step=2)
red_wine_df['quality'].hist(bins=bin_values, figsize=[14,6])
plt.title("Red Wine Original (1599 data points)")
plt.show()
